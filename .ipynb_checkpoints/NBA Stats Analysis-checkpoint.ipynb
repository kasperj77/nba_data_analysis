# %% [markdown]
# # Cleaning NBA Box Score Data

# %% [markdown]
# In this project I am going to be importing a few different data sets around NBA box scores.  I am going to want to be narrowing this down to 2017 - 2018 and limiting it to the Portland Trail Blazers.  I will be looking at doing the following to make this data more managable.
#
# * Import all data sets and combine them
# * Remove uneeded and duplicate features and find the features that are the most useful.
# * Fix Structural Errors
# * Fill in missing data
# * Normalize data

# %% [markdown]
# ## 1. Import Data

# %% [markdown]
# The first step is going to be to import both datasets for the NBA box scores.

# %%
import pandas as pd
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# Load datasets
player_box_score = '/Users/jordan.kasper/Desktop/ML_Projects/nba_box_score/playerBoxScore.csv'
team_box_score = '/Users/jordan.kasper/Desktop/ML_Projects/nba_box_score/teamBoxScore.csv'

player_dataset = read_csv(player_box_score)
team_dataset = read_csv(team_box_score)

# %% [markdown]
# ## 2. Reviewing the Data

# %% [markdown]
# After importing the data we are going to take a quick look at the raw data to see what we are dealing with.

# %%
# looking at the size of the data

print(player_dataset.shape)
print(team_dataset.shape)
# Out:
# (26109, 51)
# (2460, 123)

# %%
# reviewing the column headers

print(player_dataset.columns.values)
print(team_dataset.columns.values)
# Out:
# ['gmDate' 'gmTime' 'seasTyp' 'playLNm' 'playFNm' 'teamAbbr' 'teamConf'
#  'teamDiv' 'teamLoc' 'teamRslt' 'teamDayOff' 'offLNm1' 'offFNm1' 'offLNm2'
#  'offFNm2' 'offLNm3' 'offFNm3' 'playDispNm' 'playStat' 'playMin' 'playPos'
#  'playHeight' 'playWeight' 'playBDate' 'playPTS' 'playAST' 'playTO'
#  'playSTL' 'playBLK' 'playPF' 'playFGA' 'playFGM' 'playFG%' 'play2PA'
#  'play2PM' 'play2P%' 'play3PA' 'play3PM' 'play3P%' 'playFTA' 'playFTM'
#  'playFT%' 'playORB' 'playDRB' 'playTRB' 'opptAbbr' 'opptConf' 'opptDiv'
#  'opptLoc' 'opptRslt' 'opptDayOff']
# ['gmDate' 'gmTime' 'seasTyp' 'offLNm1' 'offFNm1' 'offLNm2' 'offFNm2'
#  'offLNm3' 'offFNm3' 'teamAbbr' 'teamConf' 'teamDiv' 'teamLoc' 'teamRslt'
#  'teamMin' 'teamDayOff' 'teamPTS' 'teamAST' 'teamTO' 'teamSTL' 'teamBLK'
#  'teamPF' 'teamFGA' 'teamFGM' 'teamFG%' 'team2PA' 'team2PM' 'team2P%'
#  'team3PA' 'team3PM' 'team3P%' 'teamFTA' 'teamFTM' 'teamFT%' 'teamORB'
#  'teamDRB' 'teamTRB' 'teamPTS1' 'teamPTS2' 'teamPTS3' 'teamPTS4'
#  'teamPTS5' 'teamPTS6' 'teamPTS7' 'teamPTS8' 'teamTREB%' 'teamASST%'
#  'teamTS%' 'teamEFG%' 'teamOREB%' 'teamDREB%' 'teamTO%' 'teamSTL%'
#  'teamBLK%' 'teamBLKR' 'teamPPS' 'teamFIC' 'teamFIC40' 'teamOrtg'
#  'teamDrtg' 'teamEDiff' 'teamPlay%' 'teamAR' 'teamAST/TO' 'teamSTL/TO'
#  'opptAbbr' 'opptConf' 'opptDiv' 'opptLoc' 'opptRslt' 'opptMin'
#  'opptDayOff' 'opptPTS' 'opptAST' 'opptTO' 'opptSTL' 'opptBLK' 'opptPF'
#  'opptFGA' 'opptFGM' 'opptFG%' 'oppt2PA' 'oppt2PM' 'oppt2P%' 'oppt3PA'
#  'oppt3PM' 'oppt3P%' 'opptFTA' 'opptFTM' 'opptFT%' 'opptORB' 'opptDRB'
#  'opptTRB' 'opptPTS1' 'opptPTS2' 'opptPTS3' 'opptPTS4' 'opptPTS5'
#  'opptPTS6' 'opptPTS7' 'opptPTS8' 'opptTREB%' 'opptASST%' 'opptTS%'
#  'opptEFG%' 'opptOREB%' 'opptDREB%' 'opptTO%' 'opptSTL%' 'opptBLK%'
#  'opptBLKR' 'opptPPS' 'opptFIC' 'opptFIC40' 'opptOrtg' 'opptDrtg'
#  'opptEDiff' 'opptPlay%' 'opptAR' 'opptAST/TO' 'opptSTL/TO' 'poss' 'pace']

# %% [markdown]
# ## 3. Merging the Data

# %%
# Merge datasets

df = pd.merge(player_dataset,team_dataset)

# %%
print(df.columns.values)
# Out:
# ['gmDate' 'gmTime' 'seasTyp' 'playLNm' 'playFNm' 'teamAbbr' 'teamConf'
#  'teamDiv' 'teamLoc' 'teamRslt' 'teamDayOff' 'offLNm1' 'offFNm1' 'offLNm2'
#  'offFNm2' 'offLNm3' 'offFNm3' 'playDispNm' 'playStat' 'playMin' 'playPos'
#  'playHeight' 'playWeight' 'playBDate' 'playPTS' 'playAST' 'playTO'
#  'playSTL' 'playBLK' 'playPF' 'playFGA' 'playFGM' 'playFG%' 'play2PA'
#  'play2PM' 'play2P%' 'play3PA' 'play3PM' 'play3P%' 'playFTA' 'playFTM'
#  'playFT%' 'playORB' 'playDRB' 'playTRB' 'opptAbbr' 'opptConf' 'opptDiv'
#  'opptLoc' 'opptRslt' 'opptDayOff' 'teamMin' 'teamPTS' 'teamAST' 'teamTO'
#  'teamSTL' 'teamBLK' 'teamPF' 'teamFGA' 'teamFGM' 'teamFG%' 'team2PA'
#  'team2PM' 'team2P%' 'team3PA' 'team3PM' 'team3P%' 'teamFTA' 'teamFTM'
#  'teamFT%' 'teamORB' 'teamDRB' 'teamTRB' 'teamPTS1' 'teamPTS2' 'teamPTS3'
#  'teamPTS4' 'teamPTS5' 'teamPTS6' 'teamPTS7' 'teamPTS8' 'teamTREB%'
#  'teamASST%' 'teamTS%' 'teamEFG%' 'teamOREB%' 'teamDREB%' 'teamTO%'
#  'teamSTL%' 'teamBLK%' 'teamBLKR' 'teamPPS' 'teamFIC' 'teamFIC40'
#  'teamOrtg' 'teamDrtg' 'teamEDiff' 'teamPlay%' 'teamAR' 'teamAST/TO'
#  'teamSTL/TO' 'opptMin' 'opptPTS' 'opptAST' 'opptTO' 'opptSTL' 'opptBLK'
#  'opptPF' 'opptFGA' 'opptFGM' 'opptFG%' 'oppt2PA' 'oppt2PM' 'oppt2P%'
#  'oppt3PA' 'oppt3PM' 'oppt3P%' 'opptFTA' 'opptFTM' 'opptFT%' 'opptORB'
#  'opptDRB' 'opptTRB' 'opptPTS1' 'opptPTS2' 'opptPTS3' 'opptPTS4'
#  'opptPTS5' 'opptPTS6' 'opptPTS7' 'opptPTS8' 'opptTREB%' 'opptASST%'
#  'opptTS%' 'opptEFG%' 'opptOREB%' 'opptDREB%' 'opptTO%' 'opptSTL%'
#  'opptBLK%' 'opptBLKR' 'opptPPS' 'opptFIC' 'opptFIC40' 'opptOrtg'
#  'opptDrtg' 'opptEDiff' 'opptPlay%' 'opptAR' 'opptAST/TO' 'opptSTL/TO'
#  'poss' 'pace']

# %% [markdown]
# ## 3. Feature Selection

# %% [markdown]
# Here we will remove any columns that we do not need to help solve our question.  We will also remove any rows that do not deal with Portland's players.

# %%
# removing teams that are not Portland

por_df = df.loc[df['teamAbbr'] == 'POR']

# %%
# reviewing the new shape

print(por_df.shape)
# Out:
# (876, 153)

# %%
por_df.head()
# Out:
#          gmDate gmTime  seasTyp   playLNm    playFNm teamAbbr teamConf  \
# 227  2017-10-18  10:00  Regular   Lillard     Damian      POR     West
# 228  2017-10-18  10:00  Regular     Aminu  Al-Farouq      POR     West
# 229  2017-10-18  10:00  Regular  Harkless    Maurice      POR     West
# 230  2017-10-18  10:00  Regular    Turner       Evan      POR     West
# 231  2017-10-18  10:00  Regular    Nurkic      Jusuf      POR     West
#
#        teamDiv teamLoc teamRslt   ...     opptFIC40 opptOrtg  opptDrtg  \
# 227  Northwest    Away      Win   ...       24.6888  76.2205  124.3598
# 228  Northwest    Away      Win   ...       24.6888  76.2205  124.3598
# 229  Northwest    Away      Win   ...       24.6888  76.2205  124.3598
# 230  Northwest    Away      Win   ...       24.6888  76.2205  124.3598
# 231  Northwest    Away      Win   ...       24.6888  76.2205  124.3598
#
#     opptEDiff opptPlay%  opptAR opptAST/TO opptSTL/TO     poss     pace
# 227  -48.1393    0.2947  8.1354      0.625      56.25  99.7107  98.8866
# 228  -48.1393    0.2947  8.1354      0.625      56.25  99.7107  98.8866
# 229  -48.1393    0.2947  8.1354      0.625      56.25  99.7107  98.8866
# 230  -48.1393    0.2947  8.1354      0.625      56.25  99.7107  98.8866
# 231  -48.1393    0.2947  8.1354      0.625      56.25  99.7107  98.8866
#
# [5 rows x 153 columns]

# %% [markdown]
# Now that we have cleaned up the non Portland teams we are going to remove the following columns that dont deal with Portland's usable features

# %%
port_df = por_df.drop(['gmTime','playFNm','playDispNm', 'seasTyp', 'teamConf','teamDiv','teamLoc','teamDayOff',
             'offLNm1','offFNm1','offLNm2','offFNm2','offLNm3','offFNm3',
             'playHeight','playWeight','playBDate','opptAbbr','opptDiv',
             'opptConf','opptLoc','opptRslt','opptDayOff','opptMin',
             'opptPTS','opptAST','opptTO','opptSTL','opptBLK','opptPF',
             'opptFGA','opptFGM','opptFG%','oppt2PA','oppt2PM','oppt2P%',
             'oppt3PA','oppt3PM','oppt3P%','opptFTA','opptFTM','opptFT%',
            'opptORB','opptDRB','opptTRB','opptPTS1','opptPTS2','opptPTS3',
            'opptPTS4','opptPTS5','opptPTS6','opptPTS7','opptPTS8','opptTREB%',
            'opptASST%','opptTS%','opptEFG%','opptOREB%','opptDREB%','opptTO%',
            'opptSTL%','opptBLK%','opptBLKR','opptPPS','opptFIC','opptFIC40','opptOrtg',
            'opptDrtg','opptEDiff','opptPlay%','opptAR','opptAST/TO','opptSTL/TO','opptSTL/TO',
            'poss','pace','teamPTS6','teamPTS7','teamPTS8','teamPTS1','teamPTS2', 'teamPTS3' ,'teamPTS4' ,'teamPTS5',
 'teamPTS8','playPos','teamMin','teamPPS','teamFIC','teamFIC40','teamOrtg','teamDrtg','teamEDiff','teamPlay%'], axis=1)

# %%
# reviewing the change in shape and the columns that are left

print(port_df.shape)
print(port_df.columns.values)
port_df.head()
# Out:
# (876, 61)
# ['gmDate' 'playLNm' 'teamAbbr' 'teamRslt' 'playStat' 'playMin' 'playPTS'
#  'playAST' 'playTO' 'playSTL' 'playBLK' 'playPF' 'playFGA' 'playFGM'
#  'playFG%' 'play2PA' 'play2PM' 'play2P%' 'play3PA' 'play3PM' 'play3P%'
#  'playFTA' 'playFTM' 'playFT%' 'playORB' 'playDRB' 'playTRB' 'teamPTS'
#  'teamAST' 'teamTO' 'teamSTL' 'teamBLK' 'teamPF' 'teamFGA' 'teamFGM'
#  'teamFG%' 'team2PA' 'team2PM' 'team2P%' 'team3PA' 'team3PM' 'team3P%'
#  'teamFTA' 'teamFTM' 'teamFT%' 'teamORB' 'teamDRB' 'teamTRB' 'teamTREB%'
#  'teamASST%' 'teamTS%' 'teamEFG%' 'teamOREB%' 'teamDREB%' 'teamTO%'
#  'teamSTL%' 'teamBLK%' 'teamBLKR' 'teamAR' 'teamAST/TO' 'teamSTL/TO']
#          gmDate   playLNm teamAbbr teamRslt playStat  playMin  playPTS  \
# 227  2017-10-18   Lillard      POR      Win  Starter       30       27
# 228  2017-10-18     Aminu      POR      Win  Starter       28        5
# 229  2017-10-18  Harkless      POR      Win  Starter       26        8
# 230  2017-10-18    Turner      POR      Win  Starter       25       12
# 231  2017-10-18    Nurkic      POR      Win  Starter       23       11
#
#      playAST  playTO  playSTL     ...      teamEFG%  teamOREB%  teamDREB%  \
# 227        5       0        1     ...        0.5667    39.4737    80.7692
# 228        2       1        0     ...        0.5667    39.4737    80.7692
# 229        2       2        0     ...        0.5667    39.4737    80.7692
# 230        3       2        1     ...        0.5667    39.4737    80.7692
# 231        1       5        1     ...        0.5667    39.4737    80.7692
#
#      teamTO%  teamSTL%  teamBLK%  teamBLKR   teamAR  teamAST/TO  teamSTL/TO
# 227  14.9601    8.0232    7.0203   10.6061  15.4581      1.2222     44.4444
# 228  14.9601    8.0232    7.0203   10.6061  15.4581      1.2222     44.4444
# 229  14.9601    8.0232    7.0203   10.6061  15.4581      1.2222     44.4444
# 230  14.9601    8.0232    7.0203   10.6061  15.4581      1.2222     44.4444
# 231  14.9601    8.0232    7.0203   10.6061  15.4581      1.2222     44.4444
#
# [5 rows x 61 columns]

# %% [markdown]
# ## 4. Checking for Null Data

# %%
# checking what rows have null info

null_data = port_df[port_df.isnull().any(axis=1)]

# %%
print(null_data)
# Out:
# Empty DataFrame
# Columns: [gmDate, playLNm, teamAbbr, teamRslt, playStat, playMin, playPTS, playAST, playTO, playSTL, playBLK, playPF, playFGA, playFGM, playFG%, play2PA, play2PM, play2P%, play3PA, play3PM, play3P%, playFTA, playFTM, playFT%, playORB, playDRB, playTRB, teamPTS, teamAST, teamTO, teamSTL, teamBLK, teamPF, teamFGA, teamFGM, teamFG%, team2PA, team2PM, team2P%, team3PA, team3PM, team3P%, teamFTA, teamFTM, teamFT%, teamORB, teamDRB, teamTRB, teamTREB%, teamASST%, teamTS%, teamEFG%, teamOREB%, teamDREB%, teamTO%, teamSTL%, teamBLK%, teamBLKR, teamAR, teamAST/TO, teamSTL/TO]
# Index: []
#
# [0 rows x 61 columns]

# %% [markdown]
# ## 5. Verifying Data

# %% [markdown]
# Now that we have the features selected and missing data handled we are going to review the data we have now to make sure it looks acurate.

# %%
# Taking a look at total number of games and players that played

print(port_df.groupby('gmDate').size())
# Out:
# gmDate
# 2017-10-18    11
# 2017-10-20    12
# 2017-10-21     9
# 2017-10-24    11
# 2017-10-26    10
# 2017-10-28     9
# 2017-10-30    10
# 2017-11-01     9
# 2017-11-02    10
# 2017-11-05     9
# 2017-11-07     9
# 2017-11-10    10
# 2017-11-13    12
# 2017-11-15    10
# 2017-11-17    12
# 2017-11-18    13
# 2017-11-20    10
# 2017-11-22    13
# 2017-11-24    10
# 2017-11-25    10
# 2017-11-27    10
# 2017-11-30    13
# 2017-12-02    11
# 2017-12-05    12
# 2017-12-09    10
# 2017-12-11    11
# 2017-12-13    11
# 2017-12-15    10
# 2017-12-16    10
# 2017-12-18     9
#               ..
# 2018-02-04     9
# 2018-02-05    13
# 2018-02-08    11
# 2018-02-09    13
# 2018-02-11    12
# 2018-02-14    10
# 2018-02-23    10
# 2018-02-24    10
# 2018-02-27    13
# 2018-03-01    10
# 2018-03-03    10
# 2018-03-05    10
# 2018-03-06    12
# 2018-03-09    12
# 2018-03-12    11
# 2018-03-15    10
# 2018-03-17    11
# 2018-03-18    13
# 2018-03-20    10
# 2018-03-23     9
# 2018-03-25    10
# 2018-03-27    10
# 2018-03-28     9
# 2018-03-30    12
# 2018-04-01    12
# 2018-04-03    10
# 2018-04-05    12
# 2018-04-07    10
# 2018-04-09    11
# 2018-04-11    12
# Length: 82, dtype: int64

# %%
port_df.loc[df['gmDate'] == '2017-10-18']
# Out:
#          gmDate      playLNm teamAbbr teamRslt playStat  playMin  playPTS  \
# 227  2017-10-18      Lillard      POR      Win  Starter       30       27
# 228  2017-10-18        Aminu      POR      Win  Starter       28        5
# 229  2017-10-18     Harkless      POR      Win  Starter       26        8
# 230  2017-10-18       Turner      POR      Win  Starter       25       12
# 231  2017-10-18       Nurkic      POR      Win  Starter       23       11
# 232  2017-10-18  Connaughton      POR      Win    Bench       32       24
# 233  2017-10-18       Napier      POR      Win    Bench       23       10
# 234  2017-10-18     Swanigan      POR      Win    Bench       18        8
# 235  2017-10-18        Davis      POR      Win    Bench       14       10
# 236  2017-10-18       Layman      POR      Win    Bench       12        3
# 237  2017-10-18      Leonard      POR      Win    Bench       11        6
#
#      playAST  playTO  playSTL     ...      teamEFG%  teamOREB%  teamDREB%  \
# 227        5       0        1     ...        0.5667    39.4737    80.7692
# 228        2       1        0     ...        0.5667    39.4737    80.7692
# 229        2       2        0     ...        0.5667    39.4737    80.7692
# 230        3       2        1     ...        0.5667    39.4737    80.7692
# 231        1       5        1     ...        0.5667    39.4737    80.7692
# 232        2       1        0     ...        0.5667    39.4737    80.7692
# 233        3       1        2     ...        0.5667    39.4737    80.7692
# 234        3       2        1     ...        0.5667    39.4737    80.7692
# 235        0       1        0     ...        0.5667    39.4737    80.7692
# 236        1       0        2     ...        0.5667    39.4737    80.7692
# 237        0       1        0     ...        0.5667    39.4737    80.7692
#
#      teamTO%  teamSTL%  teamBLK%  teamBLKR   teamAR  teamAST/TO  teamSTL/TO
# 227  14.9601    8.0232    7.0203   10.6061  15.4581      1.2222     44.4444
# 228  14.9601    8.0232    7.0203   10.6061  15.4581      1.2222     44.4444
# 229  14.9601    8.0232    7.0203   10.6061  15.4581      1.2222     44.4444
# 230  14.9601    8.0232    7.0203   10.6061  15.4581      1.2222     44.4444
# 231  14.9601    8.0232    7.0203   10.6061  15.4581      1.2222     44.4444
# 232  14.9601    8.0232    7.0203   10.6061  15.4581      1.2222     44.4444
# 233  14.9601    8.0232    7.0203   10.6061  15.4581      1.2222     44.4444
# 234  14.9601    8.0232    7.0203   10.6061  15.4581      1.2222     44.4444
# 235  14.9601    8.0232    7.0203   10.6061  15.4581      1.2222     44.4444
# 236  14.9601    8.0232    7.0203   10.6061  15.4581      1.2222     44.4444
# 237  14.9601    8.0232    7.0203   10.6061  15.4581      1.2222     44.4444
#
# [11 rows x 61 columns]

# %% [markdown]
# The above box score looks good, now that things have been cleaned up we will start to look at visualizing the data to get a better understanding of it.

# %%
column_name = "teamRslt"
df = port_df

dummies = pd.get_dummies(df[column_name],prefix=column_name)
dummies.head()

def create_dummies(df,column_name):
    dummies = pd.get_dummies(df[column_name],prefix=column_name)
    df = pd.concat([df,dummies],axis=1)
    return df

newDf = create_dummies(port_df,"teamRslt")
newDf = create_dummies(newDf,"playStat")

newDf = newDf.drop(['playStat'],axis=1)
newDf = newDf.drop(['teamRslt'],axis=1)
newDf = newDf.drop(['teamAbbr'],axis=1)
newDf = newDf.drop(['playLNm'],axis=1)
newDf = newDf.drop(['gmDate'],axis=1)



newDf.head()
# Out:
#      playMin  playPTS  playAST  playTO  playSTL  playBLK  playPF  playFGA  \
# 227       30       27        5       0        1        3       1       20
# 228       28        5        2       1        0        1       1        4
# 229       26        8        2       2        0        1       3        9
# 230       25       12        3       2        1        1       2        8
# 231       23       11        1       5        1        0       3        7
#
#      playFGM  playFG%        ...         teamSTL%  teamBLK%  teamBLKR  \
# 227       10   0.5000        ...           8.0232    7.0203   10.6061
# 228        2   0.5000        ...           8.0232    7.0203   10.6061
# 229        3   0.3333        ...           8.0232    7.0203   10.6061
# 230        4   0.5000        ...           8.0232    7.0203   10.6061
# 231        2   0.2857        ...           8.0232    7.0203   10.6061
#
#       teamAR  teamAST/TO  teamSTL/TO  teamRslt_Loss  teamRslt_Win  \
# 227  15.4581      1.2222     44.4444              0             1
# 228  15.4581      1.2222     44.4444              0             1
# 229  15.4581      1.2222     44.4444              0             1
# 230  15.4581      1.2222     44.4444              0             1
# 231  15.4581      1.2222     44.4444              0             1
#
#      playStat_Bench  playStat_Starter
# 227               0                 1
# 228               0                 1
# 229               0                 1
# 230               0                 1
# 231               0                 1
#
# [5 rows x 60 columns]

# teamDRB            -0.282723      -0.458982      0.458982        0.006103
# teamTRB            -0.118498      -0.365476      0.365476       -0.005668
# teamTREB%          -0.411649      -0.427977      0.427977        0.010488
# teamASST%          -0.099482      -0.171578      0.171578        0.013546
# teamTS%            -0.308421      -0.414592      0.414592        0.021125
# teamEFG%           -0.287923      -0.370636      0.370636        0.023263
# teamOREB%           0.000268      -0.048973      0.048973       -0.009455
# teamDREB%          -0.156906      -0.269247      0.269247        0.000045
# teamTO%            -0.658963       0.023880     -0.023880        0.031716
# teamSTL%            0.709933       0.033582     -0.033582       -0.003861
# teamBLK%           -0.012540      -0.158309      0.158309       -0.028120
# teamBLKR           -0.120957      -0.149606      0.149606       -0.022907
# teamAR             -0.039592      -0.292724      0.292724        0.016042
# teamAST/TO          0.520923      -0.143910      0.143910       -0.016330
# teamSTL/TO          1.000000       0.010084     -0.010084       -0.022817
# teamRslt_Loss       0.010084       1.000000     -1.000000       -0.001172
# teamRslt_Win       -0.010084      -1.000000      1.000000        0.001172
# playStat_Bench     -0.022817      -0.001172      0.001172        1.000000
# playStat_Starter    0.022817       0.001172     -0.001172       -1.000000
#
#                   playStat_Starter
# playMin                   0.707605
# playPTS                   0.591247
# playAST                   0.434490
# playTO                    0.381039
# playSTL                   0.290940
# playBLK                   0.215098
# playPF                    0.242199
# playFGA                   0.649475
# playFGM                   0.590602
# playFG%                   0.121160
# play2PA                   0.611464
# play2PM                   0.534148
# play2P%                   0.126703
# play3PA                   0.438470
# play3PM                   0.366592
# play3P%                   0.136123
# playFTA                   0.401709
# playFTM                   0.384210
# playFT%                   0.349546
# playORB                   0.162005
# playDRB                   0.377848
# playTRB                   0.354414
# teamPTS                   0.004901
# teamAST                  -0.008796
# teamTO                   -0.027374
# teamSTL                   0.005746
# teamBLK                   0.028790
# teamPF                    0.006914
# teamFGA                   0.032621
# teamFGM                   0.005397
# teamFG%                  -0.020016
# team2PA                   0.031364
# team2PM                   0.015881
# team2P%                  -0.011895
# team3PA                   0.001024
# team3PM                  -0.013146
# team3P%                  -0.015041
# teamFTA                   0.007115
# teamFTM                   0.007921
# teamFT%                   0.003553
# teamORB                   0.018762
# teamDRB                  -0.006103
# teamTRB                   0.005668
# teamTREB%                -0.010488
# teamASST%                -0.013546
# teamTS%                  -0.021125
# teamEFG%                 -0.023263
# teamOREB%                 0.009455
# teamDREB%                -0.000045
# teamTO%                  -0.031716
# teamSTL%                  0.003861
# teamBLK%                  0.028120
# teamBLKR                  0.022907
# teamAR                   -0.016042
# teamAST/TO                0.016330
# teamSTL/TO                0.022817
# teamRslt_Loss             0.001172
# teamRslt_Win             -0.001172
# playStat_Bench           -1.000000
# playStat_Starter          1.000000
#
# [60 rows x 60 columns]

# %%
c = newDf.corr().abs()
s = c.unstack()
so = s.sort_values(kind='quicksort').where(s > .07)
so = so.sort_values(kind='quicksort').where(s < .3)

newSo = so.dropna()
print(newSo)
# Out:
# teamFG%         teamDRB           0.070005
# teamDRB         teamFG%           0.070005
# play3P%         teamSTL/TO        0.070252
# teamSTL/TO      play3P%           0.070252
# teamBLK         playMin           0.070665
# playMin         teamBLK           0.070665
# team2P%         teamASST%         0.070806
# teamASST%       team2P%           0.070806
# teamFT%         playFT%           0.070919
# playFT%         teamFT%           0.070919
# teamTS%         playTRB           0.071327
# playTRB         teamTS%           0.071327
# teamTO%         playMin           0.071385
# playMin         teamTO%           0.071385
# teamOREB%       teamBLK           0.071586
# teamBLK         teamOREB%         0.071586
# playORB         teamSTL/TO        0.071962
# teamSTL/TO      playORB           0.071962
# teamBLKR        playDRB           0.072002
# playDRB         teamBLKR          0.072002
# teamPTS         playFTM           0.072103
# playFTM         teamPTS           0.072103
# play2PM         team2P%           0.072199
# team2P%         play2PM           0.072199
# teamBLKR        team3PM           0.072218
# team3PM         teamBLKR          0.072218
# teamPTS         playFT%           0.072266
# playFT%         teamPTS           0.072266
# teamDREB%       teamFGM           0.072531
# teamFGM         teamDREB%         0.072531
#                                     ...
# playSTL         playStat_Bench    0.290940
# playStat_Bench  playSTL           0.290940
# team3PA         teamAST/TO        0.291026
# teamAST/TO      team3PA           0.291026
# teamFT%         teamTREB%         0.291102
# teamTREB%       teamFT%           0.291102
# teamAR          team3PA           0.291144
# team3PA         teamAR            0.291144
# teamTRB         teamBLK           0.292707
# teamBLK         teamTRB           0.292707
# teamAR          teamRslt_Loss     0.292724
# teamRslt_Loss   teamAR            0.292724
# teamRslt_Win    teamAR            0.292724
# teamAR          teamRslt_Win      0.292724
# play2PM         play3PA           0.293813
# play3PA         play2PM           0.293813
# teamFGA         teamOREB%         0.293918
# teamOREB%       teamFGA           0.293918
# teamASST%       teamAST/TO        0.294477
# teamAST/TO      teamASST%         0.294477
# play3PM         play2PA           0.296883
# play2PA         play3PM           0.296883
# playTRB         playFGM           0.297139
# playFGM         playTRB           0.297139
# teamFTA         teamFGM           0.297171
# teamFGM         teamFTA           0.297171
# teamFTM         teamFGA           0.297694
# teamFGA         teamFTM           0.297694
# playDRB         playFGM           0.299694
# playFGM         playDRB           0.299694
# Length: 1142, dtype: float64

# %% [markdown]
# ## 6. Evaluating Algorithms

# %% [markdown]
# ### 6.1 Seperate out a validation dataset

# %%
# Split-out validation dataset
from sklearn.model_selection import train_test_split

array = newDf.values
X = array[:,:-1]
Y = array[:,-1]
validation_size = 0.20
seed = 7

X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=validation_size, random_state=seed)

# %%
# Spot-Check Algorithms
models = []
models.append(('LR', LogisticRegression())) 
models.append(('LDA', LinearDiscriminantAnalysis())) 
models.append(('KNN', KNeighborsClassifier())) 
models.append(('CART', DecisionTreeClassifier())) 
models.append(('NB', GaussianNB())) 
models.append(('SVM', SVC()))

# evaluate each model in turn
results = []
names = []

for name, model in models:
    kfold = KFold(n_splits=10, random_state=seed)

    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy') 
    results.append(cv_results) 
    names.append(name)

    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())

    print(msg)
# Out:
# LR: 1.000000 (0.000000)
# /anaconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# /anaconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# /anaconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# /anaconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# /anaconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# /anaconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# /anaconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# /anaconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# /anaconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# /anaconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# LDA: 0.824286 (0.060626)
# KNN: 0.687143 (0.066225)
# CART: 1.000000 (0.000000)
# NB: 1.000000 (0.000000)
# SVM: 0.671429 (0.063888)
